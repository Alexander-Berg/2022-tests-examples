# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', 1000)
import seaborn as sns
import pickle
import numpy as np
import math

# %%
FACTORS = ["area", "final_rooms_encoded", "series_name_encoded", "building_type_str_encoded", 
               "metro_foot_id_encoded", "metro_foot_time",
               "metro_transport_id_encoded", "metro_transport_time",
               "renovation", "kitchen_area", "year", 
               "ponds_time", "ponds_count", "area_segment",
           'building_min', 'building_max', 'building_mean', 'building_std', 'building_median',
'building_min_total', 'building_max_total', 'building_mean_total', 'building_median_total']

# %%
HOUSES_DB_PATH = '../../price-estimator-rest-api/data/all.houses.with.sell.price.stat.tsv'

# %%
MODEL_PATH = '../../price-estimator-rest-api/model/regions_sell_best_model.dat'

# %%
FRAUD_PATH = 'fraud.data.tsv'

# %%
ACTIVE_VOS_PATH = 'active.data.tsv'
ACTIVE_VOS_R3_OFFERS_PATH = 'active.data.r3.offers.tsv'

# %%
houses_df = pd.read_table(HOUSES_DB_PATH)

# %%
model = pickle.load(open(MODEL_PATH, "rb"))

# %%
# houses_df.head()

# %%
# ls ../../price-estimator-rest-api/model/

# %%
fraud_df = pd.read_table(FRAUD_PATH)

# %%
def clean_msc_piter(df, address_key = 'address'):
    df = df[~df[address_key].str.contains('Россия, Москва')]
    df = df[~df[address_key].str.contains('Россия, Санкт-Петербург')]
    df = df[~df[address_key].str.contains('Россия, Ленинградская область')]
    df = df[~df[address_key].str.contains('Россия, Московская область')]
    return df

# %%
print(len(fraud_df))
# Out:
# 582

# %%
fraud_df = clean_msc_piter(fraud_df)

# %%
print(len(fraud_df))
# Out:
# 546

# %%
final_df = pd.merge(fraud_df, houses_df, left_on = 'address', right_on = 'unified_address')

# %%
print(len(fraud_df))
# Out:
# 546

# %%
print(len(final_df))
# Out:
# 347

# %%
def encode_rooms(df):
    df['final_rooms_encoded'] = df.rooms
    df.loc[((df.final_rooms_encoded.isnull()) | (df.final_rooms_encoded == 0)) & (df.studio == True), 'final_rooms_encoded'] = 0
    df.loc[((df.final_rooms_encoded.isnull()) | (df.final_rooms_encoded == 0)) & (df.open_plan == True), 'final_rooms_encoded'] = 0

# %%
def addTotalPricesBasedOnArea(df):
    df['building_min_total'] = df.building_min * df.area
    df['building_max_total'] = df.building_max * df.area
    df['building_mean_total'] = df.building_mean * df.area
    df['building_median_total'] = df.building_median * df.area
    df['building_var'] = df.building_std ** 2

# %%
def add_area_segment(df):
    area_bins = [10,30,50,70,100, 1000]
    df['area_segment'] = pd.cut(df['area'], area_bins, labels=False) + 1

# %%
RENOVATION_TO_CODE = {
    'UNKNOWN': 0,
    'DESIGNER_RENOVATION': 1,
    'NEEDS_RENOVATION': 2,
    'NORMAL': 3,
    'PARTIAL_RENOVATION': 4,
    'PRIME_RENOVATION': 5,
    'RENOVATED': 6,
    'COSMETIC_DONE': 7,
    'COSMETIC_REQUIRED': 8,
    'EURO': 10,
    'GOOD': 11,

    'BEFORE_CLEAN': 12,
    'CLEAN': 13,
    'TURNKEY': 14
}
def encode_renovation(df):
    f = lambda x: RENOVATION_TO_CODE.get(x, 0)
    df['renovation'] = df['renovation'].map(f)

# %%
encode_renovation(final_df)

# %%
final_df.head()
# Out:
#      user_id             offer_id                                                                          address offer_type   category    price  renovation  area  kitchen_area  rooms  open_plan  studio  siteId          building_id    year  porches  type  hasGas  isGuarded  flats  floors  heatingType  ceilingHeight        lat  hasRubbishChute                                                                  unified_address  expectDemolition  hasSecurity  isBanned  hasLift   seriesId        lon  verba_code            series_name building_type_str  metro_foot_time metro_foot_id  metro_transport_time metro_transport_id  exp_metro_foot_time exp_metro_foot_id  exp_metro_transport_time exp_metro_transport_id  ponds_time  ponds_count  center_time  building_mean  building_median  building_min  building_max  building_std  series_name_encoded  building_type_str_encoded  metro_foot_id_encoded  metro_transport_id_encoded  exp_metro_foot_id_encoded  exp_metro_transport_id_encoded  \
# 0  411394380  1522673411449262337                Россия, Сахалинская область, Южно-Сахалинск, проспект Победы, 63Г       SELL  APARTMENT  2000000          10  68.0          12.0      2          0       0     NaN   755303642207757829  2011.0      NaN   2.0     NaN        NaN    NaN    10.0          NaN          280.0  46.946804              0.0                Россия, Сахалинская область, Южно-Сахалинск, проспект Победы, 63Г               NaN          NaN       NaN      1.0  1564812.0  142.73792   1564812.0  Индивидуальный проект           MONOLIT             1000  0_metro_foot                  1000  0_metro_transport                 1000  0_exp_metro_foot                      1000  0_exp_metro_transport        1000            0           -1  120040.833333         118750.0      102632.0      140351.0  15352.984289                   25                          4                      0                           0                          0                               0
# 1  654848724   174899699551081985                Россия, Сахалинская область, Южно-Сахалинск, проспект Победы, 63Г       SELL  APARTMENT  2000000          10  68.0          12.0      2          0       0     NaN   755303642207757829  2011.0      NaN   2.0     NaN        NaN    NaN    10.0          NaN          280.0  46.946804              0.0                Россия, Сахалинская область, Южно-Сахалинск, проспект Победы, 63Г               NaN          NaN       NaN      1.0  1564812.0  142.73792   1564812.0  Индивидуальный проект           MONOLIT             1000  0_metro_foot                  1000  0_metro_transport                 1000  0_exp_metro_foot                      1000  0_exp_metro_transport        1000            0           -1  120040.833333         118750.0      102632.0      140351.0  15352.984289                   25                          4                      0                           0                          0                               0
# 2  654838904  7757424879022759680                Россия, Сахалинская область, Южно-Сахалинск, проспект Победы, 63Г       SELL  APARTMENT  2000000          10  68.0          12.0      2          0       0     NaN   755303642207757829  2011.0      NaN   2.0     NaN        NaN    NaN    10.0          NaN          280.0  46.946804              0.0                Россия, Сахалинская область, Южно-Сахалинск, проспект Победы, 63Г               NaN          NaN       NaN      1.0  1564812.0  142.73792   1564812.0  Индивидуальный проект           MONOLIT             1000  0_metro_foot                  1000  0_metro_transport                 1000  0_exp_metro_foot                      1000  0_exp_metro_transport        1000            0           -1  120040.833333         118750.0      102632.0      140351.0  15352.984289                   25                          4                      0                           0                          0                               0
# 3  411394380  3077404908959915521  Россия, Республика Дагестан, Махачкала, Редукторный посёлок, улица Лаптиева, 53       SELL  APARTMENT  2200000           1  89.0          13.0      3          0       0     NaN  5369892064100816816  2008.0      NaN   1.0     NaN        NaN    NaN    14.0          NaN          280.0  42.966920              0.0  Россия, Республика Дагестан, Махачкала, Редукторный посёлок, улица Лаптиева, 53               NaN          NaN       NaN      1.0        NaN   47.54604         NaN                UNKNOWN             BRICK             1000  0_metro_foot                  1000  0_metro_transport                 1000  0_exp_metro_foot                      1000  0_exp_metro_transport        1000            0           -1   50222.166667          47727.5       44444.0       61017.0   6612.233977                   18                          1                      0                           0                          0                               0
# 4  654848724  1376701971863086849  Россия, Республика Дагестан, Махачкала, Редукторный посёлок, улица Лаптиева, 53       SELL  APARTMENT  1800000           1  79.0          13.0      2          0       0     NaN  5369892064100816816  2008.0      NaN   1.0     NaN        NaN    NaN    14.0          NaN          280.0  42.966920              0.0  Россия, Республика Дагестан, Махачкала, Редукторный посёлок, улица Лаптиева, 53               NaN          NaN       NaN      1.0        NaN   47.54604         NaN                UNKNOWN             BRICK             1000  0_metro_foot                  1000  0_metro_transport                 1000  0_exp_metro_foot                      1000  0_exp_metro_transport        1000            0           -1   50222.166667          47727.5       44444.0       61017.0   6612.233977                   18                          1                      0                           0                          0                               0
#
#    reconstructionYear
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
addTotalPricesBasedOnArea(final_df)

# %%
add_area_segment(final_df)

# %%
encode_rooms(final_df)

# %%
pred = model.predict(final_df[FACTORS])

# %%
round_pred = list(map(lambda price: int((price + 500) / 1000) * 1000, pred))

# %%
def get_df_for_analysis(df, pred_df, df_address_key = 'address'):
    df = df[['offer_id', df_address_key, 'area', 'price', 'renovation']]
    round_pred = list(map(lambda price: int((price + 500) / 1000) * 1000, pred_df))
    df['pred_price'] = round_pred
    df['price_pred_diff'] = (df['pred_price'] - df['price'])/df['price']
    return df

# %%
df_pred = get_df_for_analysis(final_df)
# Out:
# /Users/vgorovoy/anaconda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/vgorovoy/anaconda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# list(df_pred)

# %%
# list(final_df)

# %%
df_pred.head()
# Out:
#               offer_id                                                                          address  area    price  renovation  pred_price  price_pred_diff
# 0  1522673411449262337                Россия, Сахалинская область, Южно-Сахалинск, проспект Победы, 63Г  68.0  2000000          10     4847000         1.423500
# 1   174899699551081985                Россия, Сахалинская область, Южно-Сахалинск, проспект Победы, 63Г  68.0  2000000          10     4847000         1.423500
# 2  7757424879022759680                Россия, Сахалинская область, Южно-Сахалинск, проспект Победы, 63Г  68.0  2000000          10     4847000         1.423500
# 3  3077404908959915521  Россия, Республика Дагестан, Махачкала, Редукторный посёлок, улица Лаптиева, 53  89.0  2200000           1     4897000         1.225909
# 4  1376701971863086849  Россия, Республика Дагестан, Махачкала, Редукторный посёлок, улица Лаптиева, 53  79.0  1800000           1     4468000         1.482222

# %%
len(df_pred)
# Out:
# 347

# %%
len(df_pred[df_pred.price_pred_diff > 0.35])
# Out:
# 345

# %%
df_pred[df_pred.price_pred_diff < 0.35]
# Out:
#                 offer_id                                 address  area    price  renovation  pred_price  price_pred_diff
# 70   2520810321828934912  Россия, Тула, улица Софьи Перовской, 3  60.0  1600000          10     1851000         0.156875
# 345  2713771764945546496     Россия, Томск, Московский тракт, 68  94.0  2000000           1     2635000         0.317500

# %%
df_pred[df_pred.price_pred_diff < 0.50]
# Out:
#                 offer_id                                 address  area    price  renovation  pred_price  price_pred_diff
# 70   2520810321828934912  Россия, Тула, улица Софьи Перовской, 3  60.0  1600000          10     1851000         0.156875
# 345  2713771764945546496     Россия, Томск, Московский тракт, 68  94.0  2000000           1     2635000         0.317500

# %%
def encode_renovation_float(renovation_float):
    if (renovation_float is np.NaN) or math.isnan(renovation_float):
        renovation_encoded = 0
    else:
        renovation_encoded = int(renovation_float)
    return renovation_encoded

# %%
def encode_renovation_df_float(df):
    df['renovation'] = df['renovation'].map(encode_renovation_float)

# %%
def get_pred_df(df, houses_df, renovation_is_float = False, df_address_key = 'address'):
    final_df = pd.merge(df, houses_df, left_on = df_address_key, right_on = 'unified_address')
    if renovation_is_float:
        encode_renovation_df_float(final_df)
    else:
        encode_renovation(final_df)
    addTotalPricesBasedOnArea(final_df)
    add_area_segment(final_df)
    encode_rooms(final_df)
    pred = model.predict(final_df[FACTORS])
    df_pred = get_df_for_analysis(final_df, pred, df_address_key = df_address_key)
    return df_pred

# %%
# active_vos_df = pd.read_table(ACTIVE_VOS_PATH)
active_vos_df = pd.read_table(ACTIVE_VOS_R3_OFFERS_PATH)

# %%
active_vos_df.sample(20)
# Out:
#                  offer_id                                                                                       unified_address  type  category    price  renovation   area  kitchen_area  rooms  open_plan  studio        creation_date
# 598    527780084104930560                       Россия, Московская область, Королёв, микрорайон Первомайский, улица Кирова, 48А     1         2  5650000        11.0  76.00          10.0      4        0.0     0.0  2018-06-27 17:15:14
# 269   4258003757611758848                                                                Россия, Самара, улица 22 Партсъезда, 7     1         2  1850000        11.0  43.20           6.3      3        0.0     0.0  2018-06-27 17:23:10
# 572   1364874262769163264                                               Россия, Челябинск, улица Университетская Набережная, 64     1         2  1690000         NaN  37.00           NaN      1        0.0     0.0  2018-06-27 17:29:58
# 1131  1025073525993865728  Россия, Ленинградская область, Всеволожский район, посёлок Мурино, жилой комплекс Муринский Посад, 3     1         2  1761000         3.0  25.00           NaN      0        NaN     1.0  2018-06-27 00:11:16
# 1825   909110996875129601                                      Россия, Свердловская область, Екатеринбург, Мурзинская улица, 30     1         2  1660000        10.0  31.00           6.0      1        0.0     0.0  2018-06-27 11:03:41
# 2044  8628304072914580737                                                                Россия, Пенза, проспект Строителей, 68     1         2  1600000        11.0  35.35           6.7      1        0.0     0.0  2018-06-27 10:52:34
# 291   2019729305302670592                                          Россия, Ростов-на-Дону, поселок Орджоникидзе, улица ТУПОЛЕВА     1         2  1900000         NaN  42.00           NaN      2        0.0     0.0  2018-06-27 17:50:27
# 2008  7075082489853891328                                        Россия, Краснодар, жилой массив Пашковский, Краевая улица, 1/3     1         2  2160000         3.0  46.00          10.0      1        0.0     0.0  2018-06-27 11:43:32
# 1786  2368223848067644672          Россия, Московская область, Сергиево-Посадский район, поселок Реммаш, Институтская улица, 14     1         2  2300000         3.0  54.90           6.0      3        0.0     0.0  2018-06-27 10:10:01
# 1111  7967718448370051585                                                             Россия, Новосибирск, улица Петухова, 99/1     1         2  1265000         NaN  23.00           NaN      1        0.0     0.0  2018-06-27 06:08:28
# 472   3586544821244404225                          Россия, Нижегородская область, Бор, посёлок Октябрьский, Набережная улица, 9     1         2   900000        11.0  33.00           6.0      1        0.0     0.0  2018-06-27 11:16:16
# 1431  7480370134900410624                                                          Россия, Кемерово, Комсомольский проспект, 15     1         2  1500000         NaN  38.00           9.0      1        0.0     0.0  2018-06-27 10:14:14
# 610   8295988266204992000                           Россия, Краснодарский край, Сочи, микрорайон Центральный, улица Войкова, 35     1         2  4900000         NaN  54.00           NaN      2        0.0     0.0  2018-06-27 14:31:41
# 868   4532276296482894081                                                                   Россия, Красноярск, Советский район     1         2  3810000         NaN  79.10          13.2      3        0.0     0.0  2018-06-27 09:42:06
# 1460  7216961800878609664                                                                 Россия, Москва, Михалковская улица, 6     1         2  6500000         7.0  39.00           9.6      1        NaN     NaN  2018-06-27 06:23:23
# 1053  3662873436057434624                                                               Россия, Иваново, 3-я Лагерная улица, 53     1         2  1650000         NaN  73.00           8.0      3        0.0     0.0  2018-06-27 22:48:53
# 896   8171642206413356033                                                              Россия, Новосибирск, улица Заслонова, 13     1         2  1685000         NaN  28.80           NaN      0        NaN     1.0  2018-06-27 07:04:12
# 1101    55025435570073345                                               Россия, Московская область, Балашиха, улица Фадеева, 10     1         2  3100000         NaN  34.00           9.0      1        0.0     0.0  2018-06-27 12:05:19
# 1357  5928229635014715649                                              Россия, Московская область, Егорьевск, улица Горького, 6     1         2  1350000         NaN  45.00           NaN      2        NaN     0.0  2018-06-27 06:05:17
# 1036    15042369099991808                                    Россия, Тюмень, садовое товарищество Чайка, улица Мелиораторов, 10     1         2  1550000         NaN  32.60           5.0      1        0.0     0.0  2018-06-27 12:46:01

# %%
# active_vos_df['address_backup'] = active_vos_df['address']

# %%
def get_unified_address(row):
    result = row.address_backup
    if not 'Россия' in row.address_backup:
        result = 'Россия, ' + row.address_backup
    return result

# %%
# active_vos_df['address'] = active_vos_df.apply(get_unified_address, )

# %%
df_pred_fraud = get_pred_df(fraud_df, houses_df)
# Out:
# /Users/vgorovoy/anaconda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/vgorovoy/anaconda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df_pred_active = get_pred_df(active_vos_df, houses_df, 
                             renovation_is_float = True, df_address_key = 'unified_address')
# Out:
# /Users/vgorovoy/anaconda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/vgorovoy/anaconda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df_pred_active.sample(30)
# Out:
#                  offer_id                                                                                               unified_address  area    price  renovation  pred_price  price_pred_diff
# 84    3494707465446537985                                            Россия, Краснодар, микрорайон Гидростроителей, улица Автолюбителей  56.0  2360000          10     2518000         0.066949
# 632   3112417087454755584                                                                               Россия, Томск, проспект Мира, 5  36.0  1900000           0     1689000        -0.111053
# 919   7679693335191045121                                                                 Россия, Киров, улица Героя Николая Рожнева, 4  96.5  4352000           2     3886000        -0.107077
# 1008   230724849296926977                                                                      Россия, Краснодар, Вологодская улица, 20  77.3  4250000           0     3985000        -0.062353
# 616    948905888572135937                                                                          Россия, Киров, Современная улица, 13  34.0  1060000           2     1182000         0.115094
# 441   2310827049709739776                                                                              Россия, Омск, улица Туполева, 5Г  34.2  1400000           7     1535000         0.096429
# 822   8436905926757550593                                                   Россия, Московская область, Воскресенск, улица Калинина, 54  45.0  1400000           0     1727000         0.233571
# 904    325199143467508225                                                                    Россия, Самара, улица Советской Армии, 144  31.0  1950000           0     1765000        -0.094872
# 134   5761762765792526336                                                       Россия, Самарская область, Тольятти, улица Толстого, 13  27.0  1200000           0     1037000        -0.135833
# 93    2926009032464534273                                                    Россия, Московская область, Раменское, Северное шоссе, к21  39.5  1900000           2     2056000         0.082105
# 797   2381571071905926912                                                     Россия, Санкт-Петербург, Кронштадт, Гражданская улица, 18  88.6  5900000           0     6593000         0.117458
# 1390  5799320524985585920                                                                   Россия, Севастополь, улица Павла Дыбенко, 1  35.0  2700000           0     3338000         0.236296
# 602   5200372121911278848                                                        Россия, Республика Коми, Ухта, Первомайская улица, 35А  38.8  1750000           0     1943000         0.110286
# 569   2611892528772041472   Россия, Республика Адыгея, Тахтамукайский район, посёлок городского типа Яблоновский, Шоссейная улица, 63/5  44.0  1650000           2     1373000        -0.167879
# 221   4612746343562312960                                                  Россия, Чувашская Республика, Канаш, улица 30 лет Победы, 85  47.0  1300000          11     1250000        -0.038462
# 1179   454159504586652928                                                                             Россия, Пенза, улица Бородина, 43  33.7  1786100           0     1691000        -0.053244
# 100   3969728252402194176                                         Россия, Краснодарский край, Сочи, микрорайон Донская, улица Чехова, 4  25.0  2000000          11     1935000        -0.032500
# 1062  6689904005392510977                                                                  Россия, Ставрополь, улица Розы Люксембург, 3  56.0  2175000           0     2582000         0.187126
# 370   1542235715684115712                             Россия, Московская область, Щёлково, микрорайон Щёлково-3, улица Стефановского, 5  60.0  3599000           0     3246000        -0.098083
# 344   1390370316719498496     Россия, Свердловская область, Екатеринбург, Орджоникидзевский район, микрорайон Эльмаш, Шефская улица, 96  62.0  3700000           3     3603000        -0.026216
# 1315   298899978162835200                                                       Россия, Московская область, Химки, Московская улица, 12  43.0  4200000           0     3653000        -0.130238
# 620   8016866182757378049                                                      Россия, Калужская область, Обнинск, проспект Маркса, 124  50.0  3300000           0     3542000         0.073333
# 1334  4924462334936686081                                                                        Россия, Москва, Артековская улица, 7к5  44.0  6590000           0     6859000         0.040819
# 544   6157291895779015680  Россия, Ленинградская область, Всеволожский район, посёлок городского типа Токсово, Привокзальная улица, 20Б  28.0  1907000           3     2178000         0.142108
# 837   8042743673293196544                   Россия, Московская область, Ленинский район, деревня Бутово, жилой комплекс Бутово Парк, 29  45.0  5900000          10     6016000         0.019661
# 982     16302467273007873                                          Россия, Московская область, Егорьевск, улица Александра Невского, 24  31.0  1100000           0     1343000         0.220909
# 742   6644969956138895105                                               Россия, Омск, микрорайон Городок Нефтяников, улица 22 Апреля, 3  32.0  1650000          10     1294000        -0.215758
# 1374  3035305988949410304                                               Россия, Воронежская область, Борисоглебск, Аэродромная улица, 9  31.4  1300000           7     1158000        -0.109231
# 1023  3524948844874594304                                                              Россия, Красноярск, улица Железнодорожников, 10А  58.0  2900000           0     2835000        -0.022414
# 255   2208809887392854785                                                                       Россия, Ставрополь, улица Пирогова, 38Б  50.0  1680000           0     2055000         0.223214

# %%
print(len(df_pred_fraud))
print(len(df_pred_fraud[df_pred.price_pred_diff < 0.45]))
# Out:
# 347
# 2

# %%
print(len(df_pred_active))
print(len(df_pred_active[df_pred_active.price_pred_diff < 0.45]))
# Out:
# 1396
# 1332

# %%
df_pred_active[df_pred_active.price_pred_diff > 0.35]
# Out:
#                  offer_id                                                                                             unified_address     area     price  renovation  pred_price  price_pred_diff
# 50    3844768928362857985                                                         Россия, Республика Крым, Керчь, улица Будённого, 22    63.00   2750000           0     4498000         0.635636
# 68    1848602320425510144                                                Россия, Красноярск, микрорайон Николаевка, улица Чкалова, 41   139.00   5800000           0     8169000         0.408448
# 97    6403420819074515969                                                         Россия, Республика Крым, Ялта, улица Свердлова, 48А   108.00  13027000           0    22503000         0.727412
# 125    249243374149704448                                                                       Россия, Курган, Половинская улица, 8А    18.00    650000          11      898000         0.381538
# 130   7512430842049283840                                                     Россия, Московская область, Серпухов, улица Крюкова, 14    75.70   2850000           0     4169000         0.462807
# 1371  7919501136723730944                                                      Россия, Краснодарский край, Сочи, Теневой переулок, 32    30.00   1005000           2     2146000         1.135323
# 1372  9027451986515365632                                                  Россия, Краснодарский край, Геленджик, Крымская улица, 3к3  1210.00  21000000           0    73547000         2.502238
# 1392  6238488893688020993                                        Россия, Краснодар, микрорайон Гидростроителей, улица Гидростроителей    39.00   1350000          10     2075000         0.537037
#
# [100 rows x 7 columns]

# %%
df_pred_active_cleaned = clean_msc_piter(df_pred_active, address_key='unified_address')

# %%
df_pred_active_cleaned[df_pred_active_cleaned.price_pred_diff > 0.35]
# Out:
#                  offer_id                                                                                             unified_address     area     price  renovation  pred_price  price_pred_diff
# 50    3844768928362857985                                                         Россия, Республика Крым, Керчь, улица Будённого, 22    63.00   2750000           0     4498000         0.635636
# 68    1848602320425510144                                                Россия, Красноярск, микрорайон Николаевка, улица Чкалова, 41   139.00   5800000           0     8169000         0.408448
# 97    6403420819074515969                                                         Россия, Республика Крым, Ялта, улица Свердлова, 48А   108.00  13027000           0    22503000         0.727412
# 125    249243374149704448                                                                       Россия, Курган, Половинская улица, 8А    18.00    650000          11      898000         0.381538
# 142   5226386676868258560                                                   Россия, Вологодская область, Кириллов, улица Урицкого, 12    48.00    850000           3     1229000         0.445882
# 148   5544479556618407680                                                                      Россия, Пенза, 3-й Подгорный проезд, 6    30.00    750000           0     1242000         0.656000
# 161   8323669894199319552                          Россия, Краснодар, микрорайон Камвольно-суконный Комбинат, Магистральная улица, 11    64.00   2100000           0     2887000         0.374762
# 163   4606513874759808768                                                   Россия, Краснодарский край, Сочи, Курортный проспект, 105    80.00   7000000           0    13141000         0.877286
# 215   9039260518891515136                                              Россия, Республика Дагестан, Махачкала, улица Ирчи Казака, 37А    46.00    736000           0     1173000         0.593750
# 239   1782667675631917057                                         Россия, Республика Башкортостан, Уфа, улица Кузнецовский Затон, 20Б    19.75    889000           0     1211000         0.362205
# 240   3092641799752089601                                         Россия, Республика Башкортостан, Уфа, улица Кузнецовский Затон, 20Б    19.75    889000           0     1211000         0.362205
# 241   3659573925215822081                                         Россия, Республика Башкортостан, Уфа, улица Кузнецовский Затон, 20Б    19.75    889000           0     1211000         0.362205
# 243   6328503139089931265                                         Россия, Республика Башкортостан, Уфа, улица Кузнецовский Затон, 20Б    19.75    889000           0     1211000         0.362205
# 256   2909747166067057920                                                   Россия, Краснодарский край, Сочи, Субтропическая улица, 7    32.00   2240000           0     3560000         0.589286
# 268   5567528344072860160                                                            Россия, Челябинск, улица Братьев Кашириных, 131А    59.25   1870000           0     2798000         0.496257
# 273   4029392620001976576                                   Россия, Краснодарский край, Сочи, микрорайон Мамайка, Крымская улица, 77А    30.00   2300000           2     3347000         0.455217
# 286   7763545329189779456                                                                Россия, Ростов-на-Дону, улица Еременко, 85/2    25.00   1150000           3     1578000         0.372174
# 294    751928033993595137                                             Россия, Ростов-на-Дону, микрорайон Темерник, улица Думенко, 13Г    83.00   3800000          11     5308000         0.396842
# 307   6903385094631523328                                                                     Россия, Краснодар, Российская улица, 74    57.00   2550000           0     3922000         0.538039
# 319   2050033280137779712                                                     Россия, Краснодарский край, Сочи, Черноморская улица, 6    96.00   6200000           0    18534000         1.989355
# 334   9074669453221521408                                                   Россия, Ивановская область, Кинешма, улица Менделеева, 5А    61.00   1650000           3     2465000         0.493939
# 350   5601685280472886272                                                                     Россия, Оренбург, Ташкентская улица, 11    40.70   1170000           2     1770000         0.512821
# 1161  1690350631774804480                            Россия, Краснодарский край, Сочи, микрорайон Центральный, Первомайская улица, 19    52.00   2990000           1     8779000         1.936120
# 1192   933130235332792320                                                                          Россия, Тверь, проспект Победы, 43    64.10   1750000           0     2490000         0.422857
# 1193  6138963120012994560                                              Россия, Краснодарский край, Геленджик, Геленджикская улица, 37   192.00   5000000           2     6809000         0.361800
# 1196  8134548050153453824                                                 Россия, Краснодарский край, Сочи, улица Яна Фабрициуса, 108    29.00   1300000           2     3595000         1.765385
# 1214   776305332869685249                                                                         Россия, Томск, Алтайская улица, 159    18.00    700000           0      950000         0.357143
# 1245  4074387679941935873                                               Россия, Чувашская Республика, Чебоксары, Ярмарочная улица, 15    40.00   1490000           0     2401000         0.611409
# 1251  3730559151980045056                                    Россия, Краснодарский край, Сочи, микрорайон Донская, переулок Чехова, 8   107.00   6800000          11    10844000         0.594706
# 1263  2404246162108861184                         Россия, Челябинская область, Красноармейский район, село Миасское, улица Ленина, 53    26.80    520000           2      753000         0.448077
# 1279  5471662738231166208                                                          Россия, Республика Крым, Ялта, улица Руданского, 8   109.50  10500000           0    14661000         0.396286
# 1280  1871804964520748800                       Россия, Краснодарский край, городской округ Сочи, село Раздольное, Амбровая улица, 35    40.00   2000000          11     3230000         0.615000
# 1293  3192879390318907905                                             Россия, Краснодарский край, Геленджик, Туристическая улица, 6к8    79.80   4600000          11     7016000         0.525217
# 1338  7547259133852038912                                                                    Россия, Тверь, улица Маршала Конева, 1/3    43.00   1400000          11     2059000         0.470714
# 1371  7919501136723730944                                                      Россия, Краснодарский край, Сочи, Теневой переулок, 32    30.00   1005000           2     2146000         1.135323
# 1372  9027451986515365632                                                  Россия, Краснодарский край, Геленджик, Крымская улица, 3к3  1210.00  21000000           0    73547000         2.502238
# 1392  6238488893688020993                                        Россия, Краснодар, микрорайон Гидростроителей, улица Гидростроителей    39.00   1350000          10     2075000         0.537037
#
# [81 rows x 7 columns]

# %%
df_pred_active_cleaned[df_pred_active_cleaned.price_pred_diff > 0.35].to_csv('price_less_more_than_35_percent.tsv', index=False, sep='\t')

# %%
active_vos_all_df = pd.read_table('active.vos.sell.regions.tsv')

# %%
df_pred_active = get_pred_df(active_vos_all_df, houses_df, 
                             renovation_is_float = True, df_address_key = 'unified_address')
# Out:
# /Users/vgorovoy/anaconda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/vgorovoy/anaconda/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df_pred_active.sample(20)
# Out:
#                   offer_id                                                                            unified_address  area    price  renovation  pred_price  price_pred_diff
# 38722  7414422296374227713  Россия, Рязань, Московский административный округ, район Приокский, Октябрьская улица, 18  68.0  2300000           3     2175000        -0.054348
# 59758  2995926543921211137                                                     Россия, Челябинск, Солнечная улица, 22  63.0  1950000           0     2578000         0.322051
# 38381   858239851266051584                            Россия, Республика Марий Эл, Йошкар-Ола, Вознесенская улица, 34  73.0  3000000           0     2712000        -0.096000
# 15537  8890010347956342272                             Россия, Краснодар, микрорайон Молодёжный, Душистая улица, 79к1  40.0  1850000           7     1738000        -0.060541
# 59606  5554039335578767361                  Россия, Новгородская область, Малая Вишера, улица Заводской Домострой, 1А  28.0   699000           3      759000         0.085837
# 43903  3465944150189009665                                                  Россия, Липецк, улица Максима Горького, 1  51.0  2180000           0     2309000         0.059174
# 56767  2801119509064502272          Россия, Владимирская область, Александровский район, Струнино, Заречная улица, 12  50.0  1550000           3     1495000        -0.035484
# 4022    607737349959106561                                        Россия, Забайкальский край, Чита, 9-й микрорайон, 1  68.0  2100000           2     2111000         0.005238
# 75346  2721627740964669696                                                     Россия, Самара, Революционная улица, 3  74.0  5300000          10     5974000         0.127170
# 62550  4911064871050557184                     Россия, Чувашская Республика, Чебоксары, проспект Максима Горького, 41  38.0  1580000           0     1937000         0.225949
# 59814   226737818245554689                                                          Россия, Пенза, улица Антонова, 70  52.0  2495000           1     2868000         0.149499
# 29175  1365605812172901889                     Россия, Краснодарский край, Сочи, микрорайон Адлер, улица Ленина, 298Б  45.0  5600000           1     5735000         0.024107
# 80083   622554955645324800                                      Россия, Краснодарский край, Сочи, Славинская улица, 5  30.0  3120000           3     2183000        -0.300321
# 35852  7254156116535779584                                                    Россия, Краснодар, Тепличная улица, 104  30.0  1000000           0     1095000         0.095000
# 48621              2260193                                                   Россия, Воронеж, Студенческая улица, 12А  86.0  7500000          10     6971000        -0.070533
# 21517   564446807824586753                                                            Россия, Пенза, улица Лядова, 10  62.7  2800000           0     2491000        -0.110357
# 87511  8786441953259609857                                 Россия, Владимирская область, Александров, улица Ленина, 1  30.7  1200000           3     1063000        -0.114167
# 49478  5916039619201559809                                                          Россия, Магадан, Речная улица, 57  64.7  2100000           0     2121000         0.010000
# 77210  7420038995067215361                                                      Россия, Кемерово, Молодёжная улица, 3  91.1  8500000          10     7045000        -0.171176
# 88325  1286206853620746240                                                    Россия, Самара, Алма-Атинская улица, 38  53.4  3000000          11     3083000         0.027667

# %%
print(len(df_pred_active))
print(len(df_pred_active[df_pred_active.price_pred_diff < 0.45]))
print(len(df_pred_active[df_pred_active.price_pred_diff < 0.50]))
print(len(df_pred_active[df_pred_active.price_pred_diff < 0.80]))
print(len(df_pred_active[df_pred_active.price_pred_diff < 0.99]))
# Out:
# 93726
# 90219
# 90873
# 92532
# 92866

# %%
print(len(df_pred_active[df_pred_active.price_pred_diff >= 1]))
# Out:
# 852

# %%
df_pred_active[df_pred_active.price_pred_diff >= 1].to_csv('price_less_more_than_100_percent.tsv', index=False, sep='\t')

# %%
df_pred_active[df_pred_active.price_pred_diff >= 1].head()
# Out:
#                 offer_id                                                        unified_address  area    price  renovation  pred_price  price_pred_diff
# 71   3149986549106730753  Россия, Краснодар, Музыкальный микрорайон, улица имени Сергея Есенина  38.0   699000           0     2002000         1.864092
# 124  5971584411243704064   Россия, Краснодарский край, Сочи, микрорайон Мамайка, Волжская улица  30.0   900000           3     3345000         2.716667
# 125  1439373001459637249   Россия, Краснодарский край, Сочи, микрорайон Мамайка, Волжская улица  29.0  1200000           3     3011000         1.509167
# 126  2485168474424530176   Россия, Краснодарский край, Сочи, микрорайон Мамайка, Волжская улица  28.0  1100000           3     3138000         1.852727
# 130  2979002486036103936   Россия, Краснодарский край, Сочи, микрорайон Мамайка, Волжская улица  27.0  1161000           3     2984000         1.570198

# %%
print(len(df_pred_active[df_pred_active.price_pred_diff >= 1]))
